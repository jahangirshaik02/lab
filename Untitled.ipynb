# %% [markdown]
# <a href="https://colab.research.google.com/github/jahangirshaik02/lab/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define the quadratic function
def quadratic(x, a=-1, b=0, c=10):
    return a * x**2 + b * x + c

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the quadratic function (previously provided)
def quadratic(x, a=-1, b=0, c=10):
    return a * x**2 + b * x + c

# Define the stages of the Waterfall Model
stages = ["Requirements", "Design", "Implementation", "Verification", "Maintenance"]

# Equally spaced x positions for each stage
x_positions = np.linspace(-2, 2, len(stages))

# Compute y positions using the quadratic function
y_positions = quadratic(x_positions)

# Generate the quadratic curve for the background
x_curve = np.linspace(-2.5, 2.5, 500)
y_curve = quadratic(x_curve)

# Create a plot
plt.figure(figsize=(10, 6))

# Plot the quadratic curve (background curve)
plt.plot(x_curve, y_curve, color="blue", linestyle="--", label="Quadratic Curve")

# Add markers for each stage and create the waterfall effect
for i in range(len(stages)):
    if i > 0:
        # Draw a horizontal line connecting previous stage to current stage
        plt.plot([x_positions[i-1], x_positions[i]], [y_positions[i-1], y_positions[i-1]], color="blue", linewidth=2)
        # Draw a vertical drop from the previous stage to the current stage
        plt.plot([x_positions[i], x_positions[i]], [y_positions[i-1], y_positions[i]], color="blue", linewidth=2)

    # Place a red marker at each stage and label it
    plt.scatter(x_positions[i], y_positions[i], color="red", zorder=5)
    plt.text(x_positions[i], y_positions[i] + 0.3, stages[i], ha="center", fontsize=10)

# Title and labels
plt.title("Waterfall Model Stages", fontsize=16)
plt.xlabel("Process Step", fontsize=12)
plt.ylabel("Quadratic Output (y)", fontsize=12)
plt.grid(True)
plt.legend()

# Show the plot
plt.show()
